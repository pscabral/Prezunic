# %% [markdown]
# <a href="https://colab.research.google.com/github/pscabral/Prezunic/blob/main/Projeto001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo task=segment mode=predict model=/content/yolov8l-seg.pt conf=0.25 source="168910-1200-auto.png" save=True
# Out:
# Ultralytics YOLOv8.0.186 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l-seg summary (fused): 295 layers, 45973568 parameters, 0 gradients
#
# image 1/1 /content/168910-1200-auto.png: 640x640 1 fire hydrant, 1 bottle, 81.9ms
# Speed: 12.3ms preprocess, 81.9ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict21
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image
Image('/content/runs/segment/predict21/168910-1200-auto.png')

# %% [markdown]
# # Nova seção

# %% [markdown]
# # Nova seção
