# %%
import requests
from bs4 import BeautifulSoup
import re
from selenium import webdriver
import json
import time
from datetime import time
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import requests
#       2 from bs4 import BeautifulSoup
#       3 import re
#
# ModuleNotFoundError: No module named 'requests'

# %%
#Config
BASE_URL = "https://www.prezunic.com.br/"

PARAMS = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'DNT': '1',
    'Service-Worker-Navigation-Preload': 'true',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36',
    'sec-ch-ua': '"Chromium";v="116", "Not)A;Brand";v="24", "Google Chrome";v="116"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
}

# Criando DataFrame para receber os produtos
df_produtos = pd.DataFrame(columns=['Nome','Valor','URL Image','Categoria'])

# prezunic-mega-menu-0-x-menuDepartmentWrapper

# %%
def getItems(categoria):
    n_items = 0
    for x in range(1, 5):

        # print("Pesquisando Categoria: "+categoria+" Pág.: "+str(x))

        url = BASE_URL+str(categoria)+"?page="+str(x)
        if x == 1:
            url = BASE_URL+str(categoria)

        page = requests.get(url = url, headers = PARAMS)
        soup = BeautifulSoup(page.content, "lxml")

        notFound = soup.find_all("div", {"class": "vtex-search-result-3-x-searchNotFound flex flex-column-s flex-row-ns justify-center-ns items-center h-auto-s h5-ns"})

        if (notFound):
          break

        items = soup.find_all("div", {"class": "vtex-search-result-3-x-galleryItem vtex-search-result-3-x-galleryItem--normal vtex-search-result-3-x-galleryItem--default pa4"})

        for a in items:
            try:
                #Obtem os dados do produto
                nameItem = a.find_all("span", {"class": "prezunic-prezunic-components-0-x-ProductName"})[0].contents[0]
                priceValue = a.find_all("span", {"class": "prezunic-prezunic-components-0-x-currencyContainer"})[1].get_text()
                imageSRC = a.find("img")["src"]
                urlItem = a.find("a")["href"]

                #Insere item no DataFrame
                df_produtos.loc[len(df_produtos)] = [nameItem, priceValue, imageSRC, categoria]
                n_items += 1

            except:
                #print("erro")
                ss = 0
    print("Categoria: "+categoria+" - Items capturados.: "+str(n_items))

# %%
# Get Departamentos do Mercado
df_produtos = pd.DataFrame(columns=['Nome','Valor','URL Image','Categoria'])
# departamentos = ['bazar','bebida-alcoolica','bebida-nao-alcoolica','cama-mesa-e-banho','carnes-e-aves','congelados','frios-e-laticinios','higiene-e-beleza','hortifruti','limpeza','mercearia','padaria']
departamentos = ['mercearia','padaria']

# Iteração por Seções do Mercado
for departamento in departamentos:
  getItems(departamento)
# Out:
# Categoria: mercearia - Items capturados.: 24
# Categoria: padaria - Items capturados.: 32

# %%
#Print dos Items Capturados
df_produtos
# Out:
#                                                  Nome     Valor  \
# 0               Achocolatado em Pó Nescau Pacote 550g  R$ 11,99
# 1   Leite Condensado Moça Semi Desnatado Tetra Pak...   R$ 7,49
# 2                            Café Pilão Almofada 500g  R$ 17,98
# 3                            Tapioca da Terrinha 500g   R$ 8,19
# 4         Leite Uht Itambé Integral Caixa c/ Tampa 1l   R$ 4,99
# 5       Macarrão de Sêmola Parafuso Santa Amália 500g   R$ 4,99
# 6           Café em Pó Pilão Extra Forte a Vácuo 500g  R$ 17,98
# 7                 Achocolatado em Pó Nescau Lata 370g   R$ 8,99
# 8   Salgadinho de Milho Elma Chips Cheetos Onda Re...   R$ 3,49
# 9                    Feijão Preto Combrasil Tipo1 1Kg   R$ 8,49
# 10                Biscoito Piraquê Leite Maltado 160g   R$ 4,69
# 11             Leite Condensado Glória Tetra Pak 395g   R$ 5,59
# 12                  Feijão Preto Carreteiro Tipo1 1Kg   R$ 7,95
# 13          Macarrão de Sêmola Espaguete Aldente 750g   R$ 5,09
# 14                            Ervilha Chinezinho 500g   R$ 6,89
# 15          Café em Pó Pimpinela Golden Almofada 500g  R$ 15,98
# 16  Batata Frita Elma Chips Ruffles Cebola e Salsa...   R$ 6,99
# 17      Salgadinho de Milho Doritos Queijo Nacho 140g   R$ 9,99
# 18           Biscoito Piraquê Roladinho Goiabinha 75g   R$ 3,99
# 19                Café Pilão Tradicional a Vácuo 250g   R$ 8,99
# 20                Leite de Coco Mais Coco Vidro 200ml   R$ 3,99
# 21  Molho de Tomate Predilecta Tradicional Sachê 300g   R$ 1,99
# 22                         Coco Ralado Mais Coco 100g   R$ 3,99
# 23                    Arroz Branco Prezunic Tipo1 1Kg   R$ 5,15
# 24                Pão de Forma Plusvita Original 480g   R$ 7,49
# 25              Bolo Ana Maria Gotas de Chocolate 70g   R$ 2,49
# 26                                 Pão Francês Assado   R$ 1,08
# 27             Bolo Ana Maria Recheio de Baunilha 70g   R$ 2,49
# 28        Pão Tortilha Rap10 Pullman Tradicional 297g   R$ 9,99
# 29               Pão de Forma Prezunic Artesanal 450g   R$ 5,99
# 30                           Bisnaguito Plusvita 300g   R$ 7,49
# 31                Pão de Forma Integral Plusvita 480g   R$ 9,99
# 32  Pão de Forma Artesano Plus Vita Pão na Chapa 500g  R$ 15,50
# 33                            Pao Hot Dog Milani 400g  R$ 10,99
# 34  Pão Nutrella Integral Aveia e Sementes Clássic...  R$ 11,99
# 35  Pão Bisnaguinha Wickbold Integral Turma da Môn...   R$ 9,39
# 36                Pão Plusvita Artesano Integral 500g  R$ 13,99
# 37  Pão Integral Castanha-do-Pará e Quinoa Wickbol...  R$ 15,99
# 38      Pão Wickbold Grão Sabor Chia & Macadâmia 400g  R$ 14,99
# 39  Pão Nutrella Integral Cranberry, Quinoa e Hibi...  R$ 11,99
# 40                Torrada Crocantíssimo Churrasco 40g   R$ 3,99
# 41                  Pão Francês Congelado 240g 4 Unid   R$ 3,99
# 42                     Mini Pão Francês Jeito Caseiro   R$ 0,70
# 43  Pão Sírio Extrafino Tradicional Pita Bread Pac...  R$ 12,99
# 44                    Pão Nutrella 100% Integral 450g  R$ 13,69
# 45  Pão Nutrella Integral Semente Abóbora, Linhaça...  R$ 11,99
# 46                          Pao Milho Seven Boys 500G  R$ 10,49
# 47         Pão de Forma Wickbold Integral Frutas 500g  R$ 15,99
# 48  Bolo de Chocolate Pinguinos Recheio Baunilha C...   R$ 3,49
# 49                                    Bolo de Laranja  R$ 13,99
# 50      Pão de Forma Plusvita Integral s/ Açúcar 350g  R$ 14,49
# 51      Pão Frances Integral Congelado c/ 3 unid 180g   R$ 5,80
# 52                 Torrada de Alho Fabricação Própria   R$ 6,60
# 53                         Pão Plusvita de Milho 450g  R$ 11,90
# 54           Pão Doce Creme/Goiaba Fabricação Própria   R$ 2,69
# 55               Bolinho Bauducco Duplo Chocolate 40g   R$ 2,19
#
#                                             URL Image  Categoria
# 0   https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 1   https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 2   https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 3   https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 4   https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 5   https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 6   https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 7   https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 8   https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 9   https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 10  https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 11  https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 12  https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 13  https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 14  https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 15  https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 16  https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 17  https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 18  https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 19  https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 20  https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 21  https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 22  https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 23  https://prezunic.vtexassets.com/arquivos/ids/1...  mercearia
# 24  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 25  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 26  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 27  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 28  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 29  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 30  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 31  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 32  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 33  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 34  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 35  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 36  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 37  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 38  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 39  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 40  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 41  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 42  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 43  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 44  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 45  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 46  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 47  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 48  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 49  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 50  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 51  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 52  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 53  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 54  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria
# 55  https://prezunic.vtexassets.com/arquivos/ids/1...    padaria

# %%
import cv2
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
from urllib.request import urlretrieve
from PIL import Image
from io import BytesIO
import requests

X = []
y = []

for index, row in df_produtos.iterrows():
    response = requests.get(row['URL Image'])
    img = Image.open(BytesIO(response.content)).convert('RGB')
#     if img.mode != 'RGB':
#       img = img.convert('RGB')
    img_resized = img.resize((64, 64))
    img_array = np.array(img_resized).flatten()
#     print("Número de recursos no dataset:", img_array.shape)
    
    X.append(img_array)
    y.append(row['Nome'])

X = np.array(X)
y = np.array(y)

# Treinando o modelo
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X, y)
# Out:
# C:\Anaconda3\lib\site-packages\PIL\Image.py:992: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# KNeighborsClassifier(n_neighbors=3)

# %%
#predict from file

local_image_path = 'biscoito.png'
image = cv2.imread(local_image_path)

image_resized = cv2.resize(image, (64, 64))
image_flattened = image_resized.flatten().reshape(1, -1)

predicted_label = model.predict(image_flattened)

print("Previsão:", predicted_label)

font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(image, f'Previsao: {predicted_label[0]}', (10, 50), font, 1, (255, 0, 0), 2, cv2.LINE_AA)
cv2.imshow('Busca Produto', image)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Previsão: ['Biscoito Piraquê Leite Maltado 160g']

# %%
# Captura de webcam

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    img_resized = cv2.resize(frame, (64, 64))
    img_array = np.array(img_resized).flatten().reshape(1, -1)

    # Fazendo previsão
    prediction = model.predict(img_array)

    # Mostrar o resultado na tela
    cv2.putText(frame, str(prediction), (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2, cv2.LINE_AA)
    cv2.imshow('Reconhecimento de Produto', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
